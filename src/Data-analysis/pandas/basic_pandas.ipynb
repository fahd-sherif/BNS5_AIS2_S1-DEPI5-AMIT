# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s = pd.Series([1,2,3,4], index = ['a','b','c','d'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data = [[   [1,444,'abc'],
            [2,555,'def'],
            [3,666,'ghi'],
            [4,444,'xyz']
]]
df = pd.DataFrame(data[0], columns=["Idx","Std_id","depart"])
df
# Out:
#    Idx  Std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
display(df)
# Out:
#    Idx  Std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
df.dtypes
# Out:
# Idx       int64
# Std_id    int64
# depart      str
# dtype: object

# %%
df.dtypes
# Out:
# Idx       int64
# Std_id    int64
# depart      str
# dtype: object

# %%
df.head()
# Out:
#    Idx  Std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
df.describe()
# Out:
#             Idx      Std_id
# count  4.000000    4.000000
# mean   2.500000  527.250000
# std    1.290994  106.274409
# min    1.000000  444.000000
# 25%    1.750000  444.000000
# 50%    2.500000  499.500000
# 75%    3.250000  582.750000
# max    4.000000  666.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['Idx', 'Std_id', 'depart'], dtype='str')

# %%
df['Std_id'].unique()
df['Std_id'].nunique()
# Out:
# 3

# %%
df['Std_id'].max()
# Out:
# np.int64(444)

# %%
df['Std_id'].idxmin()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Idx     4 non-null      int64
#  1   Std_id  4 non-null      int64
#  2   depart  4 non-null      str
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
d = df['depart'].value_counts()
d
# Out:
# depart
# abc    1
# def    1
# ghi    1
# xyz    1
# Name: count, dtype: int64

# %%
df['Std_id'].sum()
# Out:
# np.int64(2109)

# %%
df.values
# Out:
# array([[1, 444, 'abc'],
#        [2, 555, 'def'],
#        [3, 666, 'ghi'],
#        [4, 444, 'xyz']], dtype=object)

# %%
df = df.replace([1,666,"abc"],"fahd",inplace= True)
df
# Out:
#     Idx Std_id depart
# 0  fahd    444   fahd
# 1     2    555    def
# 2     3   fahd    ghi
# 3     4    444    xyz

# %%
df.Std_id = df.Std_id.map({444:"sdfsdf",555:"asdasdasd"})
df
# Out:
#     Idx     Std_id depart
# 0  fahd     sdfsdf    NaN
# 1     2  asdasdasd    NaN
# 2     3        NaN    NaN
# 3     4     sdfsdf    NaN

# %%
data = [[   [1,444,'abc'],
            [2,555,'def'],
            [3,666,'ghi'],
            [4,444,'xyz']
]]
df = pd.DataFrame(data[0], columns=["Idx","Std_id","depart"])
df
# Out:
#    Idx  Std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
df.depart.iloc[2]
# Out:
# 'ghi'

# %%
df.iloc[:, 0:3]
# Out:
#    Idx  Std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz
