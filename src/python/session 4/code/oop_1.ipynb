# %%
"""


"""

class StudentInfo:
    name = "Fahd"
    age = 21

    def std_info():
        print("my name is fahd")

# %%
s1 = StudentInfo
s1.age = 22
s1.name = "Fahd Sherif"
print(s1.age)
print(s1.name)
# Out:
# 22
# Fahd Sherif
