# %% [markdown]
# Solution of Problem (Reversed Words)

# %%
text = "The greatest victory is that which requires no battle"
rev_words = " ".join(text.split()[::-1])
print(rev_words)
# Out:
# battle no requires which that is victory greatest The
